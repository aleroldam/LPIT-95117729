# %%
# ==================================
# Listas
# ==================================

# %%
lista = [1, 2, "Pink", 2.23, ['a', 'b', 3], 4]

# %%
print(lista)
# Out:
# [1, 2, 'Pink', 2.23, ['a', 'b', 3], 4]

# %%
lista
# Out:
# [1, 2, 'Pink', 2.23, ['a', 'b', 3], 4]

# %%
lista[0]
# Out:
# 1

# %%
lista[-1]
# Out:
# 4

# %%
lista[1:4]
# Out:
# [2, 'Pink', 2.23]

# %%
lista[-1]
# Out:
# 4

# %%
lista.index(2.23)
# Out:
# 3

# %%
# Modify a list element
lista[3] = 'Red'

# %%
lista
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4]

# %%
lista.append('Hello world!')

# %%
lista
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4, 'Hello world!']

# %%
lista.pop()
# Out:
# 'Hello world!'

# %%
lista
# Out:
# [1, 2, 'Pink', 'Red', ['a', 'b', 3], 4]

# %%
lista.remove('Red')

# %%
lista
# Out:
# [1, 2, 'Pink', ['a', 'b', 3], 4]

# %%
lista.insert(2, 'Red')

# %%
lista
# Out:
# [1, 2, 'Red', 'Pink', ['a', 'b', 3], 4]

# %%
# ==================================
# Tuplas
# ==================================

# %%
tupla = (1, 2, 'Pink', 2.23, ['a', 'b', 3], 4)

# %%
tupla[0]
# Out:
# 1

# %%
tupla[-1]
# Out:
# 4

# %%
print(tupla)
# Out:
# (1, 2, 'Pink', 2.23, ['a', 'b', 3], 4)

# %%
tupla = (1, 2, 3, 'John', ['One', 'Two', 3.14])

# %%
type(tupla)
# Out:
# tuple

# %%
tupla[0]
# Out:
# 1

# %%
tupla[-1]
# Out:
# ['One', 'Two', 3.14]

# %%
print(tupla)
# Out:
# (1, 2, 3, 'John', ['One', 'Two', 3.14])

# %%
tupla[2] = -1  # Tuples are read only
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 tupla[2] = -1  # Tuples are read only
#
# TypeError: 'tuple' object does not support item assignment

# %%
# ==================================
# Diccionarios
# ==================================

# %%
dicc = {1: 'Pink', 2.23: 2, 4: ['a', 'b', 3]}

# %%
type(dicc)
# Out:
# dict

# %%
print(dicc)
# Out:
# {1: 'Pink', 2.23: 2, 4: ['a', 'b', 3]}

# %%
dicc[2.23]
# Out:
# 2

# %%
dicc = {'Luna':30, -2.5:'Charlie', 'Ruby':[50, 60,70], 5:{'a':1, 'b':-2, 'c':10}}

# %%
dicc
# Out:
# {'Luna': 30,
#  -2.5: 'Charlie',
#  'Ruby': [50, 60, 70],
#  5: {'a': 1, 'b': -2, 'c': 10}}

# %%
dicc['Luna']
# Out:
# 30

# %%
dicc['Ruby'][2]
# Out:
# 70

# %%
dicc[5]['c']
# Out:
# 10

# %%
# Presence of a key in a dictionary
'Luna' in dicc
# Out:
# True

# %%
'Charlie' in dicc
# Out:
# False

# %%
# ==================================
# Make copies of sequences (lists, tuples, dictionaries)
# ==================================

# %%
lista
# Out:
# [1, 2, 'Red', 'Pink', ['a', 'b', 3], 4]

# %%
# List assignment without copy
l2 = lista

# %%
l2
# Out:
# [1, 2, 'Red', 'Pink', ['a', 'b', 3], 4]

# %%
lista[2] = 'Toni'

# %%
lista
# Out:
# [1, 2, 'Toni', 'Pink', ['a', 'b', 3], 4]

# %%
l2
# Out:
# [1, 2, 'Toni', 'Pink', ['a', 'b', 3], 4]

# %%
l2[1] = -3

# %%
lista
# Out:
# [1, -3, 'Toni', 'Pink', ['a', 'b', 3], 4]

# %%
# List assignment with copy
l3 = lista.copy()

# %%
lista
# Out:
# [1, -3, 'Toni', 'Pink', ['a', 'b', 3], 4]

# %%
l3
# Out:
# [1, -3, 'Toni', 'Pink', ['a', 'b', 3], 4]

# %%
lista[1] = 0.9

# %%
lista
# Out:
# [1, 0.9, 'Toni', 'Pink', ['a', 'b', 3], 4]

# %%
l3
# Out:
# [1, -3, 'Toni', 'Pink', ['a', 'b', 3], 4]

# %%
lista[4]
# Out:
# ['a', 'b', 3]

# %%
lista[4][1]='0xB'

# %%
lista
# Out:
# [1, 0.9, 'Toni', 'Pink', ['a', '0xB', 3], 4]

# %%
l3
# Out:
# [1, -3, 'Toni', 'Pink', ['a', '0xB', 3], 4]

# %%
from copy import deepcopy

# %%
# List assignment with deepcopy
l4 = deepcopy(lista)

# %%
l4
# Out:
# [1, 0.9, 'Toni', 'Pink', ['a', '0xB', 3], 4]

# %%
lista[4][1]='0xC'

# %%
lista
# Out:
# [1, 0.9, 'Toni', 'Pink', ['a', '0xC', 3], 4]

# %%
l4
# Out:
# [1, 0.9, 'Toni', 'Pink', ['a', '0xB', 3], 4]
